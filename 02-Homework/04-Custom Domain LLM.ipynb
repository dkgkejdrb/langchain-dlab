# %% [markdown]
# # 🧪 과제: 나만의 커스텀 도메인 LLM 체인 구현
#
# ## 🎯 과제 목표
#
# 여러분이 만들고 싶은 **커스텀 도메인 기반 LLM 시스템의 일부 기능을 직접 구현**해봅시다.
#
# ## 📌 필수 구현 요소
#
# - LangChain을 사용하여 **하나 이상의 체인을 분리하여 구성**할 것
# - 분기 조건(if 또는 RunnableBranch 등)을 포함하여 **조건에 따라 다른 체인이 실행**되도록 할 것
# - 입력 예시 1~2개와 출력 결과도 함께 준비할 것
#
#
# ## 🗣️ 발표 안내
#
# 다음 수업 시간에 2~3분 내외로 **구현한 내용과 분기 구조에 대해 발표**할 예정입니다.
# 아래 내용을 중심으로 정리해주세요:
#
# - 구현한 커스텀 도메인 및 목적
# - 분기가 적용된 구조 설명 (언제 어떤 체인이 실행되는지)
# - 실행 예시 시연 또는 출력 결과 공유
#
# ## 💡 참고
#
# - 완성도보다 **체인 분리 및 분기 흐름 설계 능력**을 중심으로 평가합니다.

# %%
# YOUR CODE
